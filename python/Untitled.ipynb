# %%
import pandas as pd

# Load the WHO suicide data
who_suicide_data = pd.read_csv('../source/MH_12.csv')
who_suicide_data
# Out:
#                            Unnamed: 0   Unnamed: 1  \
# 0    Countries, territories and areas          Sex
# 1                         Afghanistan   Both sexes
# 2                         Afghanistan         Male
# 3                         Afghanistan       Female
# 4                             Albania   Both sexes
# ..                                ...          ...
# 545                            Zambia         Male
# 546                            Zambia       Female
# 547                          Zimbabwe   Both sexes
# 548                          Zimbabwe         Male
# 549                          Zimbabwe       Female
#
#     Age-standardized suicide rates (per 100 000 population)  \
# 0                                                 2019
# 1                                        6.0 [3.4-9.9]
# 2                                       6.2 [3.5-10.5]
# 3                                        5.7 [3.2-9.2]
# 4                                        3.7 [2.1-5.7]
# ...

# %%
# Load the Economic Freedom data
excel_file_path = '../source/economic-freedom-of-the-world-2023-dataset-by-country-tables.xlsx'
excel_data = pd.ExcelFile(excel_file_path)

# Inspect sheet names
#print(excel_data.sheet_names)

# Load data from all sheets into a dictionary of dataframes
economic_data_dict = {sheet: excel_data.parse(sheet) for sheet in excel_data.sheet_names}
economic_data_dict["Mexico"]
# Out:
#    Unnamed: 0  Unnamed: 1                                Unnamed: 2    1970  \
# 0         NaN         NaN                                       NaN  Rating
# 1         NaN         NaN                                       NaN    1970
# 2         NaN         NaN                                       NaN  Rating
# 3         NaN       100.0                    Summary Ratings (Rank)    6.41
# 4      Mexico       102.0                     1. Size of Government     7.8
# ..        ...         ...                                       ...     ...
# 59     Mexico       520.0                     D. Freedom to compete     NaN
# 60     Mexico       521.0                       (i) Market openness     NaN
# 61     Mexico       522.0                     (ii) Business permits     NaN
# 62     Mexico       523.0  (iii) Distortion of business environment     NaN
# 63     Mexico         NaN                                       NaN     NaN
#
# ...

# %%
who_suicide_data['Countries']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\suicide\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Countries'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 who_suicide_data['Countries']
#
# ...

# %%
# Example cleaning process for WHO data
who_suicide_data.columns = [col.strip() for col in who_suicide_data.columns]  # Remove leading/trailing spaces
who_suicide_data['Countries'] = who_suicide_data['Countries'].str.strip()
who_suicide_data['Year'] = who_suicide_data['Year'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\suicide\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Countries, territories and areas'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 3
# ...
